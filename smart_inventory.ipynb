# %%
print("making sure this is functioning in the dev environment correctly")
# Out:
# making sure this is functioning in the dev environment correctly

# %%
# make sure you have the necessary libraries
import pandas as pd
import seaborn
import numpy as np
import random
print(f"All of the necessary libraries to fuck shit up are here.")
# Out:
# All of the necessary libraries to fuck shit up are here.

# %%
# let's read this csv as a DF

file_path = 'woop_woop.csv'
df = pd.read_csv(file_path, skiprows=1)
df.head(25)
# Out:
#                 Unnamed: 0                    Unnamed: 1 Unnamed: 2  \
# 0                      NaN                           NaN   COST/BTL
# 1          REYES  BEVERAGE                           NaN        NaN
# 2                      NaN                      Blantons       47.5
# 3                      NaN                  Kupu Bourbon         36
# 4                      NaN                 Buffalo Trace         28
# 5                    40726               Guinness Draft         161
# 6                      NaN                   Heineken bt       1.31
# 7                      NaN             Heineken light bt       1.31
# 8                      NaN              Heineken zero bt       1.13
# 9                      NaN                        Corona       1.32
# 10   Reyes Beverage Total:                           NaN        NaN
# 11                     NaN                           NaN        NaN
# 12  SOUTHERN GLAZERS OF HI                           NaN        NaN
# ...

# %%
# check out the names of the columns to make sure everything is in check
df.describe
# Out:
# <bound method NDFrame.describe of                 Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0                      NaN            NaN   COST/BTL      COUNT     AMOUNT
# 1          REYES  BEVERAGE            NaN        NaN        NaN        NaN
# 2                      NaN       Blantons       47.5        2.7     128.25
# 3                      NaN   Kupu Bourbon         36          1         36
# 4                      NaN  Buffalo Trace         28          4        112
# ..                     ...            ...        ...        ...        ...
# 297  1 case of brandy $180            NaN        NaN        NaN        NaN
# 298    1 cs ruby port $144            NaN        NaN        NaN        NaN
# 299         1 cs sake $132            NaN        NaN        NaN        NaN
# 300  1 cs cooking wine $62            NaN        NaN        NaN        NaN
# 301       Total cost: $518            NaN        NaN        NaN        NaN
#
# [302 rows x 5 columns]>
